# %%
path = f'2024_LOL.csv'
df = pd.read_csv(path, encoding='unicode-escape')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 path = f'2024_LOL.csv'
# ----> 2 df = pd.read_csv(path, encoding='unicode-escape')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
path = f'2024_LOL.csv'
df = pd.read_csv(path, encoding='unicode-escape')

# %%
df.league.unique()
# Out:
# array(['DCup', 'LEC', 'LCKC', 'LCO', 'UL', 'LLA', 'LCK', 'PRM', 'LVP SL',
#        'LFL', 'PCS', 'LJL', 'VCS', 'CBLOL', 'LCS', 'NACL', 'LPL', 'HM',
#        'GLL', 'ESLOL', 'NLC', 'TCL', 'LIT', 'LPLOL', 'LDL', 'EBL',
#        'CBLOLA', 'AL', 'HC', 'LFL2', 'NEXO', 'LRN', 'LRS', 'EM', 'MSI',
#        'LAS'], dtype=object)

# %%
lck_df = df[df.league == 'LCK']

# %%
lck_df.league.unique
# Out:
# <bound method Series.unique of 720      LCK
# 721      LCK
# 722      LCK
# 723      LCK
# 724      LCK
#         ...
# 43315    LCK
# 43316    LCK
# 43317    LCK
# 43318    LCK
# 43319    LCK
# Name: league, Length: 2904, dtype: object>

# %%
lck_df
# Out:
#                 gameid datacompleteness  url league  year   split  playoffs  \
# 720    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 721    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 722    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 723    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 724    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# ...                ...              ...  ...    ...   ...     ...       ...
# 43315  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
# 43316  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
# 43317  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
# 43318  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
# 43319  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
#
# ...

# %%
lck_df.split
# Out:
# 720      Spring
# 721      Spring
# 722      Spring
# 723      Spring
# 724      Spring
#           ...
# 43315    Spring
# 43316    Spring
# 43317    Spring
# 43318    Spring
# 43319    Spring
# Name: split, Length: 2904, dtype: object

# %%
test_id = lck_df.gameid.unique()[0]

# %%
fox_vs_bro_df = lck_df[lck_df.gameid == 'LOLTMNT01_76378']

# %%
fox_df = fox_vs_bro_df[
    (fox_vs_bro_df.teamname == 'FearX') &
    (fox_vs_bro_df.position == 'team')
]

# %%
1 == int(fox_df.void_grubs)
# Out:
# /var/folders/m5/qdqw5s0n74d93c69wxwwf4g80000gn/T/ipykernel_63339/1111351853.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   1 == int(fox_df.void_grubs)
# True

# %%
clozer_df = fox_vs_bro_df[
    (fox_vs_bro_df.teamname == 'FearX') &
    (fox_vs_bro_df.position == 'mid')
]

# %%
int(clozer_df.damagetochampions)
# Out:
# /var/folders/m5/qdqw5s0n74d93c69wxwwf4g80000gn/T/ipykernel_63339/3567881660.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   int(clozer_df.damagetochampions)
# 20645

# %%
clozer_df.champion
# Out:
# 37099    Taliyah
# Name: champion, dtype: object

# %%
Hena_df = fox_vs_bro_df[
    (fox_vs_bro_df.teamname == 'FearX') &
    (fox_vs_bro_df.position == 'bot')
]

# %%
int(Hena_df.damagetochampions)
# Out:
# /var/folders/m5/qdqw5s0n74d93c69wxwwf4g80000gn/T/ipykernel_63339/4208562072.py:1: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   int(Hena_df.damagetochampions)
# 25639

# %%
lck_team_df = lck_df[lck_df.position == 'team']

# %%
lck_team_df
# Out:
#                 gameid datacompleteness  url league  year   split  playoffs  \
# 730    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 731    LOLTMNT02_22165         complete  NaN    LCK  2024  Spring         0
# 742    LOLTMNT02_21206         complete  NaN    LCK  2024  Spring         0
# 743    LOLTMNT02_21206         complete  NaN    LCK  2024  Spring         0
# 754    LOLTMNT02_22225         complete  NaN    LCK  2024  Spring         0
# ...                ...              ...  ...    ...   ...     ...       ...
# 43283  LOLTMNT02_76146         complete  NaN    LCK  2024  Spring         1
# 43294  LOLTMNT02_76147         complete  NaN    LCK  2024  Spring         1
# 43295  LOLTMNT02_76147         complete  NaN    LCK  2024  Spring         1
# 43318  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
# 43319  LOLTMNT02_76148         complete  NaN    LCK  2024  Spring         1
#
# ...

# %%
for col in lck_team_df.columns:
    print(col)
# Out:
# gameid
# datacompleteness
# url
# league
# year
# split
# playoffs
# date
# game
# patch
# participantid
# side
# position
# playername
# playerid
# teamname
# teamid
# champion
# ban1
# ban2
# ban3
# ban4
# ban5
# pick1
# pick2
# pick3
# pick4
# pick5
# gamelength
# result
# kills
# deaths
# assists
# teamkills
# teamdeaths
# doublekills
# triplekills
# quadrakills
# pentakills
# firstblood
# firstbloodkill
# firstbloodassist
# firstbloodvictim
# team kpm
# ckpm
# firstdragon
# dragons
# opp_dragons
# elementaldrakes
# opp_elementaldrakes
# infernals
# mountains
# clouds
# oceans
# chemtechs
# hextechs
# dragons (type unknown)
# elders
# opp_elders
# firstherald
# heralds
# opp_heralds
# void_grubs
# opp_void_grubs
# firstbaron
# barons
# opp_barons
# firsttower
# towers
# opp_towers
# firstmidtower
# firsttothreetowers
# turretplates
# opp_turretplates
# inhibitors
# opp_inhibitors
# damagetochampions
# dpm
# damageshare
# damagetakenperminute
# damagemitigatedperminute
# ...

# %%
lck_team_df[lck_team_df.firsttower == 1.0].result.mean()*100
# Out:
# 66.52892561983471

# %%
lck_team_df[lck_team_df.elementaldrakes == 1.0].result.mean()*100
# Out:
# 13.636363636363635

# %%
lck_team_df[lck_team_df.firstdragon == 1.0].result.mean()*100
# Out:
# 59.50413223140496

# %%
for col in lck_df.teamname:
    print(lck_team_df[lck_team_df.firstdragon == 1.0].result.mean()*100)
# Out:
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# ...

# %%
lck_df.teamname
# Out:
# 720        DRX
# 721        DRX
# 722        DRX
# 723        DRX
# 724        DRX
#          ...
# 43315    Gen.G
# 43316    Gen.G
# 43317    Gen.G
# 43318       T1
# 43319    Gen.G
# Name: teamname, Length: 2904, dtype: object

# %%
tm_df = lck_df.teamname.unique()

# %% [markdown]
# tm_df

# %%
tm_df
# Out:
# array(['DRX', 'Nongshim RedForce', 'Gen.G', 'T1', 'OKSavingsBank BRION',
#        'Dplus KIA', 'KT Rolster', 'FearX', 'Hanwha Life Esports',
#        'Kwangdong Freecs'], dtype=object)

# %%
for cur_team in lck_df.teamname.unique():
    cur_team = lck_team_df[lck_team_df.teamname
# Out:
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
# 59.50413223140496
